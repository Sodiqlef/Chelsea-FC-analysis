# %%
#All imports 
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd

# %%
#Scraping from FBref
url = "https://fbref.com/en/squads/cff3d9bb/2024-2025/all_comps/Chelsea-Stats-All-Competitions"

# %%
tables = pd.read_html(url)

# %%
pd.set_option("display.max_columns", None)

# %%
table1 = tables[0]

# %%
table1.shape
# Out:
# (45, 34)

# %%
table1.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Playing Time               Performance                   \
#                   MP       Starts     Min   90s         Gls  Ast   G+A  G-PK
# 0                 30           27  2479.0  27.5         4.0  2.0   6.0   4.0
# 1                 28           28  2459.0  27.3        14.0  6.0  20.0  11.0
# 2                 28           28  2451.0  27.2         1.0  2.0   3.0   1.0
# ...

# %%
table1.columns
# Out:
# MultiIndex([( 'Unnamed: 0_level_0',   'Player'),
#             ( 'Unnamed: 1_level_0',   'Nation'),
#             ( 'Unnamed: 2_level_0',      'Pos'),
#             ( 'Unnamed: 3_level_0',      'Age'),
#             ( 'Unnamed: 4_level_0',       'MP'),
#             (       'Playing Time',   'Starts'),
#             (       'Playing Time',      'Min'),
#             (       'Playing Time',      '90s'),
#             (        'Performance',      'Gls'),
#             (        'Performance',      'Ast'),
#             (        'Performance',      'G+A'),
#             (        'Performance',     'G-PK'),
#             (        'Performance',       'PK'),
#             (        'Performance',    'PKatt'),
#             (        'Performance',     'CrdY'),
#             (        'Performance',     'CrdR'),
#             (           'Expected',       'xG'),
#             (           'Expected',     'npxG'),
#             (           'Expected',      'xAG'),
# ...

# %%
table1.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Playing Time               Performance                   \
#                   MP       Starts     Min   90s         Gls  Ast   G+A  G-PK
# 0                 30           27  2479.0  27.5         4.0  2.0   6.0   4.0
# 1                 28           28  2459.0  27.3        14.0  6.0  20.0  11.0
# 2                 28           28  2451.0  27.2         1.0  2.0   3.0   1.0
# ...

# %%
#Drop columns not needed for the analysis
table1 = table1.drop(columns=["Per 90 Minutes", "Unnamed: 33_level_0"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table1.head(0)
# Out:
# Empty DataFrame
# Columns: [(Unnamed: 0_level_0, Player), (Unnamed: 1_level_0, Nation), (Unnamed: 2_level_0, Pos), (Unnamed: 3_level_0, Age), (Unnamed: 4_level_0, MP), (Playing Time, Starts), (Playing Time, Min), (Playing Time, 90s), (Performance, Gls), (Performance, Ast), (Performance, G+A), (Performance, G-PK), (Performance, PK), (Performance, PKatt), (Performance, CrdY), (Performance, CrdR), (Expected, xG), (Expected, npxG), (Expected, xAG), (Expected, npxG+xAG), (Progression, PrgC), (Progression, PrgP), (Progression, PrgR)]
# Index: []

# %%
#Remove first index column
table1.columns = table1.columns.droplevel(0)

# %%
table1.head(0)
# Out:
# Empty DataFrame
# Columns: [Player, Nation, Pos, Age, MP, Starts, Min, 90s, Gls, Ast, G+A, G-PK, PK, PKatt, CrdY, CrdR, xG, npxG, xAG, npxG+xAG, PrgC, PrgP, PrgR]
# Index: []

# %%
#Remove other columns not needed
table1 = table1.drop(columns=["90s","G-PK", "npxG","npxG+xAG", "PrgC","PrgR"])

# %%
table1.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min   Gls  Ast   G+A  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0   4.0  2.0   6.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0  14.0  6.0  20.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0   1.0  2.0   3.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0   1.0  1.0   2.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0   4.0  8.0  12.0
#
#     PK  PKatt  CrdY  CrdR    xG  xAG   PrgP
# 0  0.0    0.0   8.0   1.0   1.9  1.7   84.0
# 1  3.0    3.0   4.0   0.0  14.2  8.4  154.0
# 2  0.0    0.0  10.0   0.0   0.6  2.6  136.0
# 3  0.0    0.0   6.0   0.0   0.7  1.0  105.0
# 4  0.0    0.0   6.0   0.0   4.1  4.8  144.0

# %%
#second lookout table (shooting table)
table2 = tables[16]

# %%
table2.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Standard                                               \
#                  90s      Gls  Sh SoT  SoT% Sh/90 SoT/90  G/Sh G/SoT  Dist
# 0               27.5        4  19   5  26.3  0.69   0.18  0.21  0.80  16.0
# 1               27.3       14  97  37  38.1  3.55   1.35  0.11  0.30  20.2
# 2               27.2        1  13   2  15.4  0.48   0.07  0.08  0.50  25.0
# ...

# %%
table2 = table2.drop(columns=["Expected"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table2.head(0)
# Out:
# Empty DataFrame
# Columns: [(Unnamed: 0_level_0, Player), (Unnamed: 1_level_0, Nation), (Unnamed: 2_level_0, Pos), (Unnamed: 3_level_0, Age), (Unnamed: 4_level_0, 90s), (Standard, Gls), (Standard, Sh), (Standard, SoT), (Standard, SoT%), (Standard, Sh/90), (Standard, SoT/90), (Standard, G/Sh), (Standard, G/SoT), (Standard, Dist), (Standard, FK), (Standard, PK), (Standard, PKatt), (Unnamed: 22_level_0, Matches)]
# Index: []

# %%
table2.columns = table2.columns.droplevel(0)

# %%
table2.head(0)
# Out:
# Empty DataFrame
# Columns: [Player, Nation, Pos, Age, 90s, Gls, Sh, SoT, SoT%, Sh/90, SoT/90, G/Sh, G/SoT, Dist, FK, PK, PKatt, Matches]
# Index: []

# %%
#Remove all needless tables
table2 = table2.drop(columns=["Matches", 'Nation', 'Pos', 'Age', '90s', 'Gls', 'SoT%', 'Sh/90', 'SoT/90','G/Sh', 'G/SoT', 'Dist', 'FK', 'PK', 'PKatt'])

# %%
table2.columns.unique()
# Out:
# Index(['Player', 'Sh', 'SoT'], dtype='object')

# %%
df = pd.merge(table1, table2, on="Player", how="left")

# %%
df[:3]
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min   Gls  Ast   G+A  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0   4.0  2.0   6.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0  14.0  6.0  20.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0   1.0  2.0   3.0
#
#     PK  PKatt  CrdY  CrdR    xG  xAG   PrgP    Sh   SoT
# 0  0.0    0.0   8.0   1.0   1.9  1.7   84.0  19.0   5.0
# 1  3.0    3.0   4.0   0.0  14.2  8.4  154.0  97.0  37.0
# 2  0.0    0.0  10.0   0.0   0.6  2.6  136.0  13.0   2.0

# %%
#Checking out the passing table
tables[21].head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0   Total                                  Short         \
#                  90s     Cmp     Att  Cmp%  TotDist  PrgDist    Cmp    Att
# 0               27.5  1226.0  1375.0  89.2  18922.0   5345.0  628.0  665.0
# 1               27.3   845.0  1112.0  76.0  16103.0   4235.0  347.0  406.0
# 2               27.2  1444.0  1615.0  89.4  24756.0   6602.0  653.0  707.0
# ...

# %%
#Display only the passes completed and attempted
table3 = tables[21]

# %%
table3 = table3.drop(columns=["Long", "Medium", "Short", "Expected"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table3.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0   Total                                  \
#                  90s     Cmp     Att  Cmp%  TotDist  PrgDist
# 0               27.5  1226.0  1375.0  89.2  18922.0   5345.0
# 1               27.3   845.0  1112.0  76.0  16103.0   4235.0
# 2               27.2  1444.0  1615.0  89.4  24756.0   6602.0
# 3               25.0  1753.0  1953.0  89.8  31592.0  11414.0
# ...

# %%
#Remove first column index 
table3.columns = table3.columns.droplevel(0)

# %%
table3.head()
# Out:
#            Player   Nation Pos     Age   90s     Cmp     Att  Cmp%  TotDist  \
# 0  Marc Cucurella   es ESP  DF  26-226  27.5  1226.0  1375.0  89.2  18922.0
# 1     Cole Palmer  eng ENG  MF  22-303  27.3   845.0  1112.0  76.0  16103.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  27.2  1444.0  1615.0  89.4  24756.0
# 3    Levi Colwill  eng ENG  DF  22-007  25.0  1753.0  1953.0  89.8  31592.0
# 4  Enzo Fernández   ar ARG  MF  24-047  24.4  1105.0  1357.0  81.4  19259.0
#
#    PrgDist  Ast  xAG    KP    1/3   PPA  CrsPA   PrgP  Matches
# 0   5345.0    2  1.7  14.0   90.0   7.0    2.0   84.0  Matches
# 1   4235.0    6  8.4  67.0  120.0  46.0   12.0  154.0  Matches
# 2   6602.0    2  2.6  22.0  170.0  22.0    2.0  136.0  Matches
# 3  11414.0    1  1.0  11.0  115.0   6.0    2.0  105.0  Matches
# 4   5271.0    8  4.8  50.0  111.0  27.0    3.0  144.0  Matches

# %%
table3.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', '90s', 'Cmp', 'Att', 'Cmp%',
#        'TotDist', 'PrgDist', 'Ast', 'xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP',
#        'Matches'],
#       dtype='object')

# %%
table3 = table3.drop(columns=['Nation', 'Pos', 'Age', '90s','Cmp%',
       'TotDist', 'PrgDist', 'Ast', 'xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'PrgP',
       'Matches'])

# %%
table3.head()
# Out:
#            Player     Cmp     Att
# 0  Marc Cucurella  1226.0  1375.0
# 1     Cole Palmer   845.0  1112.0
# 2  Moisés Caicedo  1444.0  1615.0
# 3    Levi Colwill  1753.0  1953.0
# 4  Enzo Fernández  1105.0  1357.0

# %%
df = pd.merge(df,table3,on="Player",how="left")

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min   Gls  Ast   G+A  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0   4.0  2.0   6.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0  14.0  6.0  20.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0   1.0  2.0   3.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0   1.0  1.0   2.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0   4.0  8.0  12.0
#
#     PK  PKatt  CrdY  CrdR    xG  xAG   PrgP    Sh   SoT     Cmp     Att
# 0  0.0    0.0   8.0   1.0   1.9  1.7   84.0  19.0   5.0  1226.0  1375.0
# 1  3.0    3.0   4.0   0.0  14.2  8.4  154.0  97.0  37.0   845.0  1112.0
# 2  0.0    0.0  10.0   0.0   0.6  2.6  136.0  13.0   2.0  1444.0  1615.0
# 3  0.0    0.0   6.0   0.0   0.7  1.0  105.0   9.0   2.0  1753.0  1953.0
# 4  0.0    0.0   6.0   0.0   4.1  4.8  144.0  37.0  14.0  1105.0  1357.0

# %%
#Rename columns for better understanding
df = df.rename(columns=
    {
        "Gls":"Goals Scored",
        "Ast":"Assists",
        "G+A":"Goals Contribution",
        "PKatt":"Attempted PK",
        "CrdY":"Yellow Cards",
        "CrdR":"Red Cards",
        "PrgP":"Progressive Passes",
        "Sh":"Total Shorts",
        "SoT":"Shorts on Target",
        "cmp":"Completed Passes",
        "Att":"Attended Passes"
        
    })

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#The chances creation table
table4 = tables[26]

# %%
table4.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Pass Types                           \
#                  90s                Att       Live   Dead    FK    TB    Sw
# 0               27.5             1375.0     1193.0  179.0  22.0   2.0   0.0
# 1               27.3             1112.0      936.0  170.0  40.0  18.0  10.0
# 2               27.2             1615.0     1567.0   45.0  29.0   9.0  10.0
# ...

# %%
table4 = table4.drop(columns=["Corner Kicks", "Outcomes"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table4.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Unnamed: 5_level_0 Pass Types                           \
#                  90s                Att       Live   Dead    FK    TB    Sw
# 0               27.5             1375.0     1193.0  179.0  22.0   2.0   0.0
# 1               27.3             1112.0      936.0  170.0  40.0  18.0  10.0
# 2               27.2             1615.0     1567.0   45.0  29.0   9.0  10.0
# ...

# %%
#Remove first column index
table4.columns = table4.columns.droplevel(0)

# %%
table4.head(0)
# Out:
# Empty DataFrame
# Columns: [Player, Nation, Pos, Age, 90s, Att, Live, Dead, FK, TB, Sw, Crs, TI, CK, Matches]
# Index: []

# %%
#Drop other needless columns
table4.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', '90s', 'Att', 'Live', 'Dead', 'FK',
#        'TB', 'Sw', 'Crs', 'TI', 'CK', 'Matches'],
#       dtype='object')

# %%
table4 = table4.drop(columns=['Nation', 'Pos', 'Age', '90s', 'Att', 'Live', 'Dead', 'Sw', 'Matches'])

# %%
table4.head()
# Out:
#            Player    FK    TB  Crs     TI    CK
# 0  Marc Cucurella  22.0   2.0   26  157.0   0.0
# 1     Cole Palmer  40.0  18.0  118   13.0  70.0
# 2  Moisés Caicedo  29.0   9.0    8   16.0   0.0
# 3    Levi Colwill  57.0   3.0   10    5.0   0.0
# 4  Enzo Fernández  41.0  12.0   73    3.0  49.0

# %%
#Merge table 4 with the dataframe
df = pd.merge(df,table4,on="Player", how="left")

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#Get the Defensive stats from the chances creation table
table5 = tables[36]

# %%
table5.head()
# Out:
#   Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0 Unnamed: 3_level_0  \
#               Player             Nation                Pos                Age
# 0     Marc Cucurella             es ESP                 DF             26-226
# 1        Cole Palmer            eng ENG                 MF             22-303
# 2     Moisés Caicedo             ec ECU                 MF             23-123
# 3       Levi Colwill            eng ENG                 DF             22-007
# 4     Enzo Fernández             ar ARG                 MF             24-047
#
#   Unnamed: 4_level_0 Tackles                              Challenges        \
#                  90s     Tkl TklW Def 3rd Mid 3rd Att 3rd        Tkl   Att
# 0               27.5    46.0   35    25.0    18.0     3.0       21.0  41.0
# 1               27.3    20.0   12    11.0     5.0     4.0        7.0  18.0
# 2               27.2    78.0   50    31.0    40.0     7.0       39.0  64.0
# ...

# %%
table5 = table5.drop(columns=["Challenges"])
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\pandas\core\generic.py:4153: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
table5.columns = table5.columns.droplevel(0)

# %%
table5.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', '90s', 'Tkl', 'TklW', 'Def 3rd',
#        'Mid 3rd', 'Att 3rd', 'Blocks', 'Sh', 'Pass', 'Int', 'Tkl+Int', 'Clr',
#        'Err', 'Matches'],
#       dtype='object')

# %%
table5 = table5.drop(columns=['Nation', 'Pos', 'Age', '90s','Def 3rd', 'Mid 3rd', 'Att 3rd','Sh', 'Pass','Tkl+Int','Matches'])

# %%
table5.head()
# Out:
#            Player   Tkl  TklW  Blocks  Int   Clr  Err
# 0  Marc Cucurella  46.0    35    35.0   22  51.0  3.0
# 1     Cole Palmer  20.0    12    13.0    8  11.0  1.0
# 2  Moisés Caicedo  78.0    50    36.0   36  38.0  0.0
# 3    Levi Colwill  32.0    21    28.0   26  78.0  3.0
# 4  Enzo Fernández  53.0    29    26.0   13  16.0  4.0

# %%
df = pd.merge(df, table5, on="Player", how="left")

# %%
#get subs stats
table6 = tables[46]

# %%
table6.columns = table6.columns.droplevel(0)

# %%
df["Substitue"] = table6["Subs"].values

# %%
df["Unused Substitue"] = table6["unSub"].values

# %%
table7 = tables[51]

# %%
#Remove first column index
table7.columns = table7.columns.droplevel(0)

# %%
table7.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', '90s', 'CrdY', 'CrdR', '2CrdY', 'Fls',
#        'Fld', 'Off', 'Crs', 'Int', 'TklW', 'PKwon', 'PKcon', 'OG', 'Recov',
#        'Won', 'Lost', 'Won%', 'Matches'],
#       dtype='object')

# %%
df["Fouls Committed"] = table7["Fls"]

# %%
df["Fouls drawn"] = table7["Fld"]

# %%
df["Offsides"] = table7["Off"]

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#Rename unclear columns
df = df.rename(columns={
    "FK":"Free Kick",
    "TB":"Through Balls",
    "Crs":"Crosses",
    "TI":"Throw Ins",
    "CK":"Corner Kicks",
    "Tkl":"Tackles",
    "TklW":"Tackels Won",
    "Int":"Interceptions",
    "Clr":"Clearance",
    "Err":"Errors"
    
})

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#Drop all players that have not played in any match
df = df[df["MP"].values !=0]

# %%
df.shape
# Out:
# (37, 37)

# %%
df.head()
# Out:
#            Player   Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella   es ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer  eng ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo   ec ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill  eng ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández   ar ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#Standardize the nation column
df["Nation"] = df["Nation"].str[-3:]
# Out:
# <ipython-input-104-3f839734c4ab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Nation"] = df["Nation"].str[-3:]

# %%
df.head()
# Out:
#            Player Nation Pos     Age  MP  Starts     Min  Goals Scored  \
# 0  Marc Cucurella    ESP  DF  26-226  30      27  2479.0           4.0
# 1     Cole Palmer    ENG  MF  22-303  28      28  2459.0          14.0
# 2  Moisés Caicedo    ECU  MF  23-123  28      28  2451.0           1.0
# 3    Levi Colwill    ENG  DF  22-007  25      25  2249.0           1.0
# 4  Enzo Fernández    ARG  MF  24-047  29      24  2198.0           4.0
#
#    Assists  Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards  \
# 0      2.0                 6.0  0.0           0.0           8.0        1.0
# 1      6.0                20.0  3.0           3.0           4.0        0.0
# 2      2.0                 3.0  0.0           0.0          10.0        0.0
# 3      1.0                 2.0  0.0           0.0           6.0        0.0
# 4      8.0                12.0  0.0           0.0           6.0        0.0
#
#      xG  xAG  Progressive Passes  Total Shorts  Shorts on Target     Cmp  \
# ...

# %%
#standardize the age column by showing only the year
df["Age"] = df["Age"].str[0:2]
# Out:
# <ipython-input-106-c08ca1f10875>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Age"] = df["Age"].str[0:2]

# %%
df.head()
# Out:
#            Player Nation Pos Age  MP  Starts     Min  Goals Scored  Assists  \
# 0  Marc Cucurella    ESP  DF  26  30      27  2479.0           4.0      2.0
# 1     Cole Palmer    ENG  MF  22  28      28  2459.0          14.0      6.0
# 2  Moisés Caicedo    ECU  MF  23  28      28  2451.0           1.0      2.0
# 3    Levi Colwill    ENG  DF  22  25      25  2249.0           1.0      1.0
# 4  Enzo Fernández    ARG  MF  24  29      24  2198.0           4.0      8.0
#
#    Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards    xG  xAG  \
# 0                 6.0  0.0           0.0           8.0        1.0   1.9  1.7
# 1                20.0  3.0           3.0           4.0        0.0  14.2  8.4
# 2                 3.0  0.0           0.0          10.0        0.0   0.6  2.6
# 3                 2.0  0.0           0.0           6.0        0.0   0.7  1.0
# 4                12.0  0.0           0.0           6.0        0.0   4.1  4.8
#
# ...

# %%
#rename cmp to completed passes
df = df.rename(columns={"Cmp":"Completed Passes"})

# %%
df.head()
# Out:
#            Player Nation Pos Age  MP  Starts     Min  Goals Scored  Assists  \
# 0  Marc Cucurella    ESP  DF  26  30      27  2479.0           4.0      2.0
# 1     Cole Palmer    ENG  MF  22  28      28  2459.0          14.0      6.0
# 2  Moisés Caicedo    ECU  MF  23  28      28  2451.0           1.0      2.0
# 3    Levi Colwill    ENG  DF  22  25      25  2249.0           1.0      1.0
# 4  Enzo Fernández    ARG  MF  24  29      24  2198.0           4.0      8.0
#
#    Goals Contribution   PK  Attempted PK  Yellow Cards  Red Cards    xG  xAG  \
# 0                 6.0  0.0           0.0           8.0        1.0   1.9  1.7
# 1                20.0  3.0           3.0           4.0        0.0  14.2  8.4
# 2                 3.0  0.0           0.0          10.0        0.0   0.6  2.6
# 3                 2.0  0.0           0.0           6.0        0.0   0.7  1.0
# 4                12.0  0.0           0.0           6.0        0.0   4.1  4.8
#
# ...

# %%
#Check data types
df.dtypes
# Out:
# Player                 object
# Nation                 object
# Pos                    object
# Age                    object
# MP                      int64
# Starts                  int64
# Min                   float64
# Goals Scored          float64
# Assists               float64
# Goals Contribution    float64
# PK                    float64
# Attempted PK          float64
# Yellow Cards          float64
# Red Cards             float64
# xG                    float64
# xAG                   float64
# Progressive Passes    float64
# Total Shorts          float64
# Shorts on Target      float64
# Completed Passes      float64
# Attended Passes       float64
# Free Kick             float64
# Through Balls         float64
# Crosses               float64
# Throw Ins             float64
# Corner Kicks          float64
# Tackles               float64
# Tackels Won           float64
# Blocks                float64
# Interceptions         float64
# Clearance             float64
# ...

# %%
#First, fill all NA with 0
df = df.fillna(value=0)

# %%
df.columns
# Out:
# Index(['Player', 'Nation', 'Pos', 'Age', 'MP', 'Starts', 'Min', 'Goals Scored',
#        'Assists', 'Goals Contribution', 'PK', 'Attempted PK', 'Yellow Cards',
#        'Red Cards', 'xG', 'xAG', 'Progressive Passes', 'Total Shorts',
#        'Shorts on Target', 'Completed Passes', 'Attended Passes', 'Free Kick',
#        'Through Balls', 'Crosses', 'Throw Ins', 'Corner Kicks', 'Tackles',
#        'Tackels Won', 'Blocks', 'Interceptions', 'Clearance', 'Errors',
#        'Substitue', 'Unused Substitue', 'Fouls Committed', 'Fouls drawn',
#        'Offsides'],
#       dtype='object')

# %%
df[['Min', 'Goals Scored',
       'Assists', 'Goals Contribution', 'PK', 'Attempted PK', 'Yellow Cards',
       'Red Cards', 'Progressive Passes', 'Total Shorts',
       'Shorts on Target', 'Completed Passes', 'Attended Passes', 'Free Kick',
       'Through Balls', 'Crosses', 'Throw Ins', 'Corner Kicks', 'Tackles',
       'Tackels Won', 'Blocks', 'Interceptions', 'Clearance', 'Errors', 'Age', 'Fouls Committed', 'Fouls drawn',
       'Offsides']] = df[['Min', 'Goals Scored',
       'Assists', 'Goals Contribution', 'PK', 'Attempted PK', 'Yellow Cards',
       'Red Cards', 'Progressive Passes', 'Total Shorts',
       'Shorts on Target', 'Completed Passes', 'Attended Passes', 'Free Kick',
       'Through Balls', 'Crosses', 'Throw Ins', 'Corner Kicks', 'Tackles',
       'Tackels Won', 'Blocks', 'Interceptions', 'Clearance', 'Errors', 'Age', 'Fouls Committed', 'Fouls drawn',
       'Offsides']].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37 entries, 0 to 36
# Data columns (total 37 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Player              37 non-null     object
#  1   Nation              37 non-null     object
#  2   Pos                 37 non-null     object
#  3   Age                 37 non-null     int64
#  4   MP                  37 non-null     int64
#  5   Starts              37 non-null     int64
#  6   Min                 37 non-null     int64
#  7   Goals Scored        37 non-null     int64
#  8   Assists             37 non-null     int64
#  9   Goals Contribution  37 non-null     int64
#  10  PK                  37 non-null     int64
#  11  Attempted PK        37 non-null     int64
#  12  Yellow Cards        37 non-null     int64
#  13  Red Cards           37 non-null     int64
#  14  xG                  37 non-null     float64
#  15  xAG                 37 non-null     float64
# ...

# %%
#Check summary
df.describe()
# Out:
#              Age         MP     Starts          Min  Goals Scored    Assists  \
# count  37.000000  37.000000  37.000000    37.000000     37.000000  37.000000
# mean   22.459459  14.675676  11.000000   989.945946      2.324324   1.621622
# std     3.033101  10.203632   9.246621   807.365123      3.559448   2.112809
# min    17.000000   1.000000   0.000000     5.000000      0.000000   0.000000
# 25%    21.000000   6.000000   4.000000   368.000000      0.000000   0.000000
# 50%    22.000000  13.000000   9.000000   858.000000      0.000000   1.000000
# 75%    25.000000  24.000000  19.000000  1626.000000      4.000000   2.000000
# max    28.000000  32.000000  28.000000  2479.000000     14.000000   8.000000
#
#        Goals Contribution         PK  Attempted PK  Yellow Cards  Red Cards  \
# count           37.000000  37.000000     37.000000     37.000000  37.000000
# mean             3.945946   0.135135      0.162162      2.405405   0.054054
# ...

# %%
df.head()
# Out:
#            Player Nation Pos  Age  MP  Starts   Min  Goals Scored  Assists  \
# 0  Marc Cucurella    ESP  DF   26  30      27  2479             4        2
# 1     Cole Palmer    ENG  MF   22  28      28  2459            14        6
# 2  Moisés Caicedo    ECU  MF   23  28      28  2451             1        2
# 3    Levi Colwill    ENG  DF   22  25      25  2249             1        1
# 4  Enzo Fernández    ARG  MF   24  29      24  2198             4        8
#
#    Goals Contribution  PK  Attempted PK  Yellow Cards  Red Cards    xG  xAG  \
# 0                   6   0             0             8          1   1.9  1.7
# 1                  20   3             3             4          0  14.2  8.4
# 2                   3   0             0            10          0   0.6  2.6
# 3                   2   0             0             6          0   0.7  1.0
# 4                  12   0             0             6          0   4.1  4.8
#
# ...

# %%
#Export to csv
df.to_csv("Chelsea dataset.csv")
